# %%
def mysum(x):
  s = x[0]
  soma = s
  for i in range(len(x)-1):
    soma += x[i+1]
  return soma


print(mysum([1,2,3]))
print(mysum(["hello ,","world!"]))
print(mysum([[1,2],[3,4]]))
# Out:
# 6
# hello ,world!
# [1, 2, 3, 4]
