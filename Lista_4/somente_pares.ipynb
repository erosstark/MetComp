# %%
def somente_pares( list):
  list_pares =[]
  for i in range(0,len(list)):
    if list[i] %2 == 0:
      list_pares.append(list[i])
  return list_pares

y = [1,2,3,22,23,33,34]
print(somente_pares(y))
# Out:
# [2, 22, 34]
