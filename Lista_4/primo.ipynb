# %%
def primo (x):
  i = x-1
  if i == 0:
    primo = True
  else:
   while x %i != 0:
    i -= 1
    if i == 1:
      primo = True
    else:
      primo = False
  return primo
x = int(input("x= "))
print("%d é primo  ="%x ,primo(x))
