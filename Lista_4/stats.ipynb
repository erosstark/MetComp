# %%
import numpy as np

def stats(valores: np.array):
  num_elementos = np.size(valores)
  print(num_elementos)

  maior_valor = np.max(valores)
  menor_valor = np.min(valores)
  print(maior_valor,menor_valor)

  soma = np.sum(valores)
  print(soma)

  media = np.mean(valores)
  print(media)

  desv_padrao = np.std(valores,ddof = 1)
  print(desv_padrao)

lista =[]


i = input("digita ai")
while i !=  "fim":
  i = float(i)
  lista.append(i)
  i = input("digita ai")


array = np.array(lista)
valores = stats(array)
print(array)

"""
deixa bonitinho colocando as explicaçoes (;)
"""
# Out:
# digita ai20
# digita ai10
# digita ai5
# digita aifim
# 3
# 20.0 5.0
# 35.0
# 11.666666666666666
# 7.637626158259733
# [20. 10.  5.]
