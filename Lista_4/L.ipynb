# %%
# Aproximação da função ln(1+x)

from math import log

def L(x,n):
  i = 1
  soma = 0
  for i in range(1,n+1):
    soma += (1 / i) * ((x / (1 + x)) ** i)
    i += 1
  return soma
print(L(1.5,5))
print(log(2.5))
# Out:
# 0.899952
# 0.9162907318741551
