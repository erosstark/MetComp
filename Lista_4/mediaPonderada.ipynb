# %%
 def mediaPonderada(n1,n2,peso1=1,peso2=1):
  """
  Cacula a média ponderada poderada de dois números n1 e n2.
  """
  media = (n1 + n2) / (peso1 + peso2)
  return media

n1 = float(input("n1 "))
n2 = float(input("n2 "))
print("a média é: %f " %mediaPonderada(n1,n2))
# Out:
# n1 10
# n2 5
# a média é: 7.500000
