# %%
import numpy as np

notas= np.loadtxt("/content/drive/MyDrive/Colab Notebooks/Lista 3/notas.txt")

# soma das notas
soma = 0
for c in notas:
 soma += c
print(soma)

#numero de alunos
alunos_total = 0
for i in notas:
  alunos_total += 1
print(alunos_total)

# media (soma das notas / numero de alunos)
media = soma / alunos_total
print(media)

# desvio padrao
x=0
for i in notas:
  x += i**2
desv = (x /(alunos_total - 1)) - ((alunos_total * media**2) / alunos_total - 1)
desv = np.sqrt(desv)
print("d",desv)
print(np.std(notas,ddof=1))

# numero de  alunos que passaram

alunos_aprovados = 0
for i in notas:
  if i >= 7:
    alunos_aprovados += 1
print(alunos_aprovados)

# porcentagem que passaram

porc_ap=alunos_aprovados * 100 / alunos_total
print(porc_ap)

#numeros de alunos reprovados

alunos_reprovados = 0
for i in notas:
  if i < 3:
    alunos_reprovados += 1
print(alunos_reprovados)

# porcentagem de alunos reprovados

porc_rep = alunos_reprovados * 100 / alunos_total
print(porc_rep)

"""
deixa isso bonito falta terminar os detalhes do exercicio
"""
# Out:
# 401.4
# 78
# 5.146153846153846
# d 2.365599634485303
# 2.0620688330237362
# 14
# 17.94871794871795
# 13
# 16.666666666666668
