# %%
R = 0.01097
m=3
n = 5
t=[]
for  m in range(1,m+1):
  print(m)

  for n in range (n-4,n+1):                    # So ajeitar a exibiçao pra ficar bonito (:
    n=n+1
    L = 1 / (R * ((1/m**2)- (1/n**2)))

    t.append(L)
  print(t)
# Out:
# 1
# [121.5436037678517, 102.55241567912488, 97.23488301428137, 94.95594044363415, 93.76220862091418]
# 2
# [121.5436037678517, 102.55241567912488, 97.23488301428137, 94.95594044363415, 93.76220862091418, 656.3354603463993, 486.1744150714068, 434.084299170899, 410.2096627164995, 397.04243897498225]
# 3
# [121.5436037678517, 102.55241567912488, 97.23488301428137, 94.95594044363415, 93.76220862091418, 656.3354603463993, 486.1744150714068, 434.084299170899, 410.2096627164995, 397.04243897498225, 1875.2441724182836, 1281.9051959890612, 1093.8924339106654, 1005.013673655424, 954.6697605038536]
