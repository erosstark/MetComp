# %%
import numpy as np
from math import factorial
import matplotlib.pyplot as plt

def taylor_seno(x,N):
  """
  Retorna uma aproximação para seno(x) usando a série de Taylor.
  x deve ser dado em radianos.
  N é o expoente do termo até onde a série será calculada.

  Ex:
  X = 3 * np.pi / 2
  N = 7
  y = taylor_seno(x,N)

  A série será calculada até o termo com expoente 7.

  """
  senx = 0
  for n in range(0,(N//2)+1):
    senx += (((-1) ** n) * (x **(2 * n + 1))) / factorial(2 * n + 1)
  return senx



# Para x = pi/6 e 3pi/4.
Ns = [3,5,7]
xs = [np.pi/6, 3*np.pi/4]
xstr = ["pi/6","3pi/4"]        # Texto para ser exibido.
i = 0                          # index da lista do texto a ser exibido.

for x in xs:

  for N in Ns:

    # Aproximação usando a série de Taylor.
    sin_aprox = taylor_seno(x,N)
    print("N = %d  x = %s \nValor aproximado do seno(%s) é: %f" %(N, xstr[i], xstr[i], sin_aprox))

    # Diferença entre a aproximação e o valor obtido com np.sin(x).
    print("Diferença entre a aproximação e np.sin(%s) = %f " %(xstr[i], abs(np.sin(x) - sin_aprox)))

    # Proximo termo da série.
    prox_termo = taylor_seno(x,N+2) - taylor_seno(x,N)
    print("Valor do próximo termo da série : %f \n " %( prox_termo))

  i += 1



# Valores de x para plotar o gráfico

x = np.linspace(0, 3*np.pi/2, 51)

# Gráfico np.sin(x)
plt.plot(x, np.sin(x),"r")

# Gráfico N=3
N=3
y3 = taylor_seno(x,N)
plt.plot(x,y3,"g")

# Gráfico N=5
N=5
y5 = taylor_seno(x,N)
plt.plot(x,y5)

# Gráfico N=7
N=7
y7 = taylor_seno(x,N)
plt.plot(x,y7,"b")


# Gráfico N=9
N=9
y9 = taylor_seno(x,N)
plt.plot(x,y9,"y")


# Formatação do gráfico
plt.ylim(top = 2, bottom = -2)
plt.xticks(np.linspace(0, 25*np.pi/18, 6),['0','50','100','150','200','250'])
plt.title("Série de Taylor - Sen(x)")
plt.xlabel("x(graus)")
plt.ylabel("Sen(x)")
plt.legend(["Sen(x)","N=3" , "N=5", "N=7","N=9"])
plt.grid(True)


plt.savefig("seno.png")
plt.show()
# Out:
# N = 3  x = pi/6
# Valor aproximado do seno(pi/6) é: 0.499674
# Diferença entre a aproximação e np.sin(pi/6) = 0.000326
# Valor do próximo termo da série : 0.000328
#
# N = 5  x = pi/6
# Valor aproximado do seno(pi/6) é: 0.500002
# Diferença entre a aproximação e np.sin(pi/6) = 0.000002
# Valor do próximo termo da série : -0.000002
#
# N = 7  x = pi/6
# Valor aproximado do seno(pi/6) é: 0.500000
# Diferença entre a aproximação e np.sin(pi/6) = 0.000000
# Valor do próximo termo da série : 0.000000
#
# N = 3  x = 3pi/4
# Valor aproximado do seno(3pi/4) é: 0.176066
# Diferença entre a aproximação e np.sin(3pi/4) = 0.531041
# Valor do próximo termo da série : 0.605166
#
# N = 5  x = 3pi/4
# Valor aproximado do seno(3pi/4) é: 0.781232
# Diferença entre a aproximação e np.sin(3pi/4) = 0.074125
# Valor do próximo termo da série : -0.079992
#
# N = 7  x = 3pi/4
# Valor aproximado do seno(3pi/4) é: 0.701239
# Diferença entre a aproximação e np.sin(3pi/4) = 0.005867
# Valor do próximo termo da série : 0.006168
