# %%
import numpy as np
import matplotlib.pyplot as plt

gravidade = np.loadtxt(r"C:\Users\eross\OneDrive\Documents\vscode python\MetComp\Lista_5\gravidade.txt")

media = np.mean(gravidade)
desv_padrao = np.std(gravidade, ddof = 1)

plt.hist(gravidade, bins = 20, density = False, edgecolor = "b")

plt.figtext(0.15, 0.8, fr"Valor médio $\sigma$={media:.2f}cm/$s^2$ \
\nDesvio padrao $\mu$={desv_padrao:.2f}",backgroundcolor = (0, 0.5, 1, 0.5))
# Out:
# Text(0.15, 0.8, 'Valor médio $\\sigma$=985.97cm/$s^2$ \\\n\\nDesvio padrao $\\mu$=2.01')
