# %%
# Calcula o máximo divisor comum entre dois números

m = int(input("m"))
n = int(input("n"))

if m > n:
  d = n
  i = n - 1
  while m % d != 0:
    while n % i != 0:
      i = i - 1
    d = i
  print (d)

else:
  i = m
  d = i
  while m % d != 1:
    i = d
    while n % i != 1:
      i = m - 1
    d = i
  print(d)
  
  
####################################################################
# Fiz melhor
####################################################################

# Calcula o máximo divisor comum entre dois números

numero1 = int(input("número 1  "))
numero2 = int(input("numero 2  "))

divisor = numero2+1
while divisor > 0:
    divisor -=1
    if numero1 % divisor == 0 and numero2 % divisor == 0:
        break
print(divisor)
# Out:
# m14
# n10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c9b32a2a707a> in <cell line: 6>()
#       7   d = n
#       8   i = n - 1
# ----> 9   while m % d != 0:
#      10     while n % i != 0:
#      11       i = i - 1
#
# KeyboardInterrupt:
