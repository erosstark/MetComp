# %%
# Exibe os n multiplos de i ou j ou ambos.

n = int(input("n"))
i = int(input("i"))
j = int(input("j"))

m = 0
contador = 0
while contador < n:
  if m * i != m * j:
    print(m * i)
    print(m * j)
    contador += 2
    m += 1
  else:
    print(m * i)
    contador += 1
    m += 1
# Out:
# 0
# 3
# 6
# 6
# 12
