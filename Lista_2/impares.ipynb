# %%
# Imprime n números ímpares e sua soma.

n = int(input("Digite um número inteiro positivo "))
s = 0
i = 1
p = 1
print(f"os {n} primeiros naturais ímpares são")
while p <= n:
  print(i)
  s = s + i
  i += 2
  p += 1
print("a soma dos %d primeiros ímpares é %d" %(n,s))
# Out:
# Digite um número inteiro positivo 0
# os 0 primeiros naturais ímpares são
# a soma dos 0 primeiros ímpares é 0
