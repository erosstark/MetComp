# %%
# Testa a conjectura de Collatz.

n = int(input("Digite um número inteiro positivo "))

i=n
while i > 1:
  n = i
  if i % 2 == 0:
    i = n // 2
    print(i)
  else:
    i = n * 3 + 1
    print(i)
# Out:
# Digite um número inteiro positivo 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
# Out:
# 2
