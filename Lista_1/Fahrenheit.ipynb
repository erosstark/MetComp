# %%
#Programa que converte Celsius para Fahrenheit

temperatura_celsius = float(input("Insira a temperatura em Celsius "))

#formula de conversâo
fahrenheit = (9/5)*temperatura_celsius+32

#exibe a conversâo na tela
print(fahrenheit,"°F")
# Out:
# Insira a temperatura em Celsius 10
# 50.0 °F
